# %% [markdown]
# ### Frequency Encoding

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize']=[15,6]

# %%
sales=pd.read_csv('~/Downloads/train_XnW6LSF.csv')
sales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
mapped=sales.Item_Type.value_counts(normalize=True).to_dict()

# %%
# Map the item type on the basis of frequency %age
sales['Item_Type_Percent']=sales.Item_Type.map(mapped)
sales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales  Item_Type_Percent
# 0     Supermarket Type1          3735.1380           0.080019
# 1     Supermarket Type2           443.4228           0.052212
# 2     Supermarket Type1          2097.2700           0.049865
# 3         Grocery Store           732.3800           0.144550
# 4     Supermarket Type1           994.7052           0.106770
# ...                 ...                ...                ...
# 8518  Supermarket Type1          2778.3834           0.140795
# 8519  Supermarket Type1           549.2850           0.076030
# 8520  Supermarket Type1          1193.1136           0.061011
# 8521  Supermarket Type2          1845.5976           0.140795
# 8522  Supermarket Type1           765.6700           0.052212
#
# [8523 rows x 13 columns]

# %%
sales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales  Item_Type_Percent
# 0     Supermarket Type1          3735.1380           0.080019
# 1     Supermarket Type2           443.4228           0.052212
# 2     Supermarket Type1          2097.2700           0.049865
# 3         Grocery Store           732.3800           0.144550
# 4     Supermarket Type1           994.7052           0.106770
# ...                 ...                ...                ...
# 8518  Supermarket Type1          2778.3834           0.140795
# 8519  Supermarket Type1           549.2850           0.076030
# 8520  Supermarket Type1          1193.1136           0.061011
# 8521  Supermarket Type2          1845.5976           0.140795
# 8522  Supermarket Type1           765.6700           0.052212
#
# [8523 rows x 13 columns]

# %% [markdown]
# ### Target Encoding on Outlet Id

# %%
mapped=sales.groupby('Outlet_Identifier')['Item_Outlet_Sales'].median().to_dict()

# %%
sales['Outlet_ID']=sales.Outlet_Identifier.map(mapped)

# %%
sales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales  Item_Type_Percent  Outlet_ID
# 0     Supermarket Type1          3735.1380           0.080019  1966.1074
# 1     Supermarket Type2           443.4228           0.052212  1655.1788
# 2     Supermarket Type1          2097.2700           0.049865  1966.1074
# 3         Grocery Store           732.3800           0.144550   250.3408
# 4     Supermarket Type1           994.7052           0.106770  2050.6640
# ...                 ...                ...                ...        ...
# 8518  Supermarket Type1          2778.3834           0.140795  2050.6640
# 8519  Supermarket Type1           549.2850           0.076030  1834.9448
# 8520  Supermarket Type1          1193.1136           0.061011  2109.2544
# 8521  Supermarket Type2          1845.5976           0.140795  1655.1788
# 8522  Supermarket Type1           765.6700           0.052212  1945.8005
#
# [8523 rows x 14 columns]

# %%
sales.loc[:,['Outlet_ID','Item_Outlet_Sales']].corr()
# Out:
#                    Outlet_ID  Item_Outlet_Sales
# Outlet_ID           1.000000           0.489391
# Item_Outlet_Sales   0.489391           1.000000

# %% [markdown]
# ### Binning the Cat variables

# %%
sales.Item_Type.unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
# Perishables and Non-Persishables
perish=['Dairy','Meat', 'Fruits and Vegetables','Breakfast','Breads', 'Starchy Foods', 'Seafood']

# %%
def perish_ables(x):
    if x in perish:
        return('Perishables')
    else:
        return('Non_Perishables')

# %%
sales['Item_Type_Cat']=sales.Item_Type.apply(perish_ables)

# %%
sales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales  Item_Type_Percent  Outlet_ID  \
# 0     Supermarket Type1          3735.1380           0.080019  1966.1074
# 1     Supermarket Type2           443.4228           0.052212  1655.1788
# 2     Supermarket Type1          2097.2700           0.049865  1966.1074
# 3         Grocery Store           732.3800           0.144550   250.3408
# 4     Supermarket Type1           994.7052           0.106770  2050.6640
# ...                 ...                ...                ...        ...
# 8518  Supermarket Type1          2778.3834           0.140795  2050.6640
# 8519  Supermarket Type1           549.2850           0.076030  1834.9448
# 8520  Supermarket Type1          1193.1136           0.061011  2109.2544
# 8521  Supermarket Type2          1845.5976           0.140795  1655.1788
# 8522  Supermarket Type1           765.6700           0.052212  1945.8005
#
#         Item_Type_Cat
# 0         Perishables
# 1     Non_Perishables
# 2         Perishables
# 3         Perishables
# 4     Non_Perishables
# ...               ...
# 8518  Non_Perishables
# 8519  Non_Perishables
# 8520  Non_Perishables
# 8521  Non_Perishables
# 8522  Non_Perishables
#
# [8523 rows x 15 columns]

# %%
## Drop the Item Type,Outlet Est year and Outlet ID

newsales=sales.drop(['Outlet_Establishment_Year','Outlet_Identifier'],axis=1)

# %%
newsales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Size Outlet_Location_Type  \
# 0                     Dairy  249.8092      Medium               Tier 1
# 1               Soft Drinks   48.2692      Medium               Tier 3
# 2                      Meat  141.6180      Medium               Tier 1
# 3     Fruits and Vegetables  182.0950         NaN               Tier 3
# 4                 Household   53.8614        High               Tier 3
# ...                     ...       ...         ...                  ...
# 8518            Snack Foods  214.5218        High               Tier 3
# 8519           Baking Goods  108.1570         NaN               Tier 2
# 8520     Health and Hygiene   85.1224       Small               Tier 2
# 8521            Snack Foods  103.1332      Medium               Tier 3
# 8522            Soft Drinks   75.4670       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales  Item_Type_Percent  Outlet_ID  \
# 0     Supermarket Type1          3735.1380           0.080019  1966.1074
# 1     Supermarket Type2           443.4228           0.052212  1655.1788
# 2     Supermarket Type1          2097.2700           0.049865  1966.1074
# 3         Grocery Store           732.3800           0.144550   250.3408
# 4     Supermarket Type1           994.7052           0.106770  2050.6640
# ...                 ...                ...                ...        ...
# 8518  Supermarket Type1          2778.3834           0.140795  2050.6640
# 8519  Supermarket Type1           549.2850           0.076030  1834.9448
# 8520  Supermarket Type1          1193.1136           0.061011  2109.2544
# 8521  Supermarket Type2          1845.5976           0.140795  1655.1788
# 8522  Supermarket Type1           765.6700           0.052212  1945.8005
#
#         Item_Type_Cat
# 0         Perishables
# 1     Non_Perishables
# 2         Perishables
# 3         Perishables
# 4     Non_Perishables
# ...               ...
# 8518  Non_Perishables
# 8519  Non_Perishables
# 8520  Non_Perishables
# 8521  Non_Perishables
# 8522  Non_Perishables
#
# [8523 rows x 13 columns]

# %% [markdown]
# ## Feature Engineering

# %%
# Extracting the first 02 letters from the Item ID

sales.Item_Identifier[0][:2]
# Out:
# 'FD'

# %%
ids=[]
for i in newsales.Item_Identifier:
    ids.append(i[:2])

# %%
newsales['Item_Identifier']=pd.Series(ids)
newsales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0                 FD        9.300          Low Fat         0.016047
# 1                 DR        5.920          Regular         0.019278
# 2                 FD       17.500          Low Fat         0.016760
# 3                 FD       19.200          Regular         0.000000
# 4                 NC        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518              FD        6.865          Low Fat         0.056783
# 8519              FD        8.380          Regular         0.046982
# 8520              NC       10.600          Low Fat         0.035186
# 8521              FD        7.210          Regular         0.145221
# 8522              DR       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Size Outlet_Location_Type  \
# 0                     Dairy  249.8092      Medium               Tier 1
# 1               Soft Drinks   48.2692      Medium               Tier 3
# 2                      Meat  141.6180      Medium               Tier 1
# 3     Fruits and Vegetables  182.0950         NaN               Tier 3
# 4                 Household   53.8614        High               Tier 3
# ...                     ...       ...         ...                  ...
# 8518            Snack Foods  214.5218        High               Tier 3
# 8519           Baking Goods  108.1570         NaN               Tier 2
# 8520     Health and Hygiene   85.1224       Small               Tier 2
# 8521            Snack Foods  103.1332      Medium               Tier 3
# 8522            Soft Drinks   75.4670       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales  Item_Type_Percent  Outlet_ID  \
# 0     Supermarket Type1          3735.1380           0.080019  1966.1074
# 1     Supermarket Type2           443.4228           0.052212  1655.1788
# 2     Supermarket Type1          2097.2700           0.049865  1966.1074
# 3         Grocery Store           732.3800           0.144550   250.3408
# 4     Supermarket Type1           994.7052           0.106770  2050.6640
# ...                 ...                ...                ...        ...
# 8518  Supermarket Type1          2778.3834           0.140795  2050.6640
# 8519  Supermarket Type1           549.2850           0.076030  1834.9448
# 8520  Supermarket Type1          1193.1136           0.061011  2109.2544
# 8521  Supermarket Type2          1845.5976           0.140795  1655.1788
# 8522  Supermarket Type1           765.6700           0.052212  1945.8005
#
#         Item_Type_Cat
# 0         Perishables
# 1     Non_Perishables
# 2         Perishables
# 3         Perishables
# 4     Non_Perishables
# ...               ...
# 8518  Non_Perishables
# 8519  Non_Perishables
# 8520  Non_Perishables
# 8521  Non_Perishables
# 8522  Non_Perishables
#
# [8523 rows x 13 columns]

# %%
newsales.Item_Identifier.unique()
# Out:
# array(['FD', 'DR', 'NC'], dtype=object)

# %%
# Boxplot between Item_id and sales
sns.boxplot(x='Item_Identifier',y='Item_Outlet_Sales',data=newsales)
# Out:
# <AxesSubplot:xlabel='Item_Identifier', ylabel='Item_Outlet_Sales'>

# %%
# Item_Fat_Content
newsales.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
newsales.Item_Fat_Content.replace(to_replace=['LF','low fat','reg'],value=['Low Fat','Low Fat','Regular'],inplace=True)

# %%
newsales.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
sns.boxplot(data=newsales,x='Item_Fat_Content',y='Item_Outlet_Sales')
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>

# %%
sns.violinplot(data=newsales,x='Item_Fat_Content',y='Item_Outlet_Sales')
plt.axhline(7500,color='r')

# %%
sns.distplot(newsales['Item_Outlet_Sales'],kde=True)
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
newsales.groupby('Item_Fat_Content')['Item_Outlet_Sales'].describe()
# Out:
#                    count         mean          std      min       25%  \
# Item_Fat_Content
# Low Fat           5517.0  2157.711534  1697.973824  33.2900  826.2578
# Regular           3006.0  2224.561170  1721.480865  33.9558  857.5504
#
#                         50%         75%         max
# Item_Fat_Content
# Low Fat           1765.0358  3050.69560  13086.9648
# Regular           1844.5989  3198.66965  12117.5600

# %%
# Replacing the Item Fat Content with Non Edible where the Item ID is NC
newsales.loc[newsales.Item_Identifier=='NC','Item_Fat_Content']="Non Edible"
newsales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0                 FD        9.300          Low Fat         0.016047
# 1                 DR        5.920          Regular         0.019278
# 2                 FD       17.500          Low Fat         0.016760
# 3                 FD       19.200          Regular         0.000000
# 4                 NC        8.930       Non Edible         0.000000
# ...              ...          ...              ...              ...
# 8518              FD        6.865          Low Fat         0.056783
# 8519              FD        8.380          Regular         0.046982
# 8520              NC       10.600       Non Edible         0.035186
# 8521              FD        7.210          Regular         0.145221
# 8522              DR       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Size Outlet_Location_Type  \
# 0                     Dairy  249.8092      Medium               Tier 1
# 1               Soft Drinks   48.2692      Medium               Tier 3
# 2                      Meat  141.6180      Medium               Tier 1
# 3     Fruits and Vegetables  182.0950         NaN               Tier 3
# 4                 Household   53.8614        High               Tier 3
# ...                     ...       ...         ...                  ...
# 8518            Snack Foods  214.5218        High               Tier 3
# 8519           Baking Goods  108.1570         NaN               Tier 2
# 8520     Health and Hygiene   85.1224       Small               Tier 2
# 8521            Snack Foods  103.1332      Medium               Tier 3
# 8522            Soft Drinks   75.4670       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales  Item_Type_Percent  Outlet_ID  \
# 0     Supermarket Type1          3735.1380           0.080019  1966.1074
# 1     Supermarket Type2           443.4228           0.052212  1655.1788
# 2     Supermarket Type1          2097.2700           0.049865  1966.1074
# 3         Grocery Store           732.3800           0.144550   250.3408
# 4     Supermarket Type1           994.7052           0.106770  2050.6640
# ...                 ...                ...                ...        ...
# 8518  Supermarket Type1          2778.3834           0.140795  2050.6640
# 8519  Supermarket Type1           549.2850           0.076030  1834.9448
# 8520  Supermarket Type1          1193.1136           0.061011  2109.2544
# 8521  Supermarket Type2          1845.5976           0.140795  1655.1788
# 8522  Supermarket Type1           765.6700           0.052212  1945.8005
#
#         Item_Type_Cat
# 0         Perishables
# 1     Non_Perishables
# 2         Perishables
# 3         Perishables
# 4     Non_Perishables
# ...               ...
# 8518  Non_Perishables
# 8519  Non_Perishables
# 8520  Non_Perishables
# 8521  Non_Perishables
# 8522  Non_Perishables
#
# [8523 rows x 13 columns]

# %%
# Replacing 0s in Item Visibility
newsales.groupby('Item_Identifier')['Item_Visibility'].transform(lambda x: x.replace(to_replace = 0,value=x.median()))
# Out:
# 0       0.016047
# 1       0.019278
# 2       0.016760
# 3       0.056406
# 4       0.044999
#           ...
# 8518    0.056783
# 8519    0.046982
# 8520    0.035186
# 8521    0.145221
# 8522    0.044878
# Name: Item_Visibility, Length: 8523, dtype: float64

# %%
sns.scatterplot(x='Item_Visibility',y='Item_Outlet_Sales',data=newsales,color='magenta')
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_Outlet_Sales'>

# %%
# Impute the Outlet size with mode
newsales.Outlet_Size.value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
pd.DataFrame(newsales.groupby(['Outlet_Type','Outlet_Location_Type'])['Outlet_Size'].count()).T
# Out:
# Outlet_Type          Grocery Store        Supermarket Type1                \
# Outlet_Location_Type        Tier 1 Tier 3            Tier 1 Tier 2 Tier 3
# Outlet_Size                    528      0              1860    930    932
#
# Outlet_Type          Supermarket Type2 Supermarket Type3
# Outlet_Location_Type            Tier 3            Tier 3
# Outlet_Size                        928               935

# %%
pd.DataFrame(newsales.groupby(['Outlet_Size','Outlet_Location_Type'])['Outlet_Type'].count()).T
# Out:
# Outlet_Size            High Medium         Small
# Outlet_Location_Type Tier 3 Tier 1 Tier 3 Tier 1 Tier 2
# Outlet_Type             932    930   1863   1458    930

# %%
# Mode Imputation
value=newsales.Outlet_Size.mode()[0]
newsales.Outlet_Size.fillna(value,inplace=True)
newsales.isna().sum()
# Out:
# Item_Identifier            0
# Item_Weight             1463
# Item_Fat_Content           0
# Item_Visibility            0
# Item_Type                  0
# Item_MRP                   0
# Outlet_Size                0
# Outlet_Location_Type       0
# Outlet_Type                0
# Item_Outlet_Sales          0
# Item_Type_Percent          0
# Outlet_ID                  0
# Item_Type_Cat              0
# dtype: int64

# %% [markdown]
# ## Outlier Removal
#
# * Using Boxplot :: **Any value > Q3+1.5*IQR** or **Any value < Q1-1.5*IQR is known** as **Outlier**.
# * Using Z Scores :: If **Z Score is > 3** or if **Z Score < -3** is termed as **Outlier**.

# %%
newsales.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# Calculate the IQR and other Quantiles

q1=newsales.quantile(0.25)
q3=newsales.quantile(0.75)
iqr = q3 - q1

upper_lim = q3+1.5*iqr
lower_lim = q1-1.5*iqr

# %%
# Condition

# Data without outliers

# ~ Not operator meeting the reverse criterion
# .any(axis=1) : returns the any row where the conditions are met
# | : Either or that means if the conditions are met either in lower lim or in upper limit
newsales.loc[~((newsales<lower_lim) | (newsales>upper_lim)).any(axis=1)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0                 FD        9.300          Low Fat         0.016047
# 1                 DR        5.920          Regular         0.019278
# 2                 FD       17.500          Low Fat         0.016760
# 4                 NC        8.930       Non Edible         0.000000
# 5                 FD       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8518              FD        6.865          Low Fat         0.056783
# 8519              FD        8.380          Regular         0.046982
# 8520              NC       10.600       Non Edible         0.035186
# 8521              FD        7.210          Regular         0.145221
# 8522              DR       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Size Outlet_Location_Type  \
# 0                  Dairy  249.8092      Medium               Tier 1
# 1            Soft Drinks   48.2692      Medium               Tier 3
# 2                   Meat  141.6180      Medium               Tier 1
# 4              Household   53.8614        High               Tier 3
# 5           Baking Goods   51.4008      Medium               Tier 3
# ...                  ...       ...         ...                  ...
# 8518         Snack Foods  214.5218        High               Tier 3
# 8519        Baking Goods  108.1570      Medium               Tier 2
# 8520  Health and Hygiene   85.1224       Small               Tier 2
# 8521         Snack Foods  103.1332      Medium               Tier 3
# 8522         Soft Drinks   75.4670       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales  Item_Type_Percent  Outlet_ID  \
# 0     Supermarket Type1          3735.1380           0.080019  1966.1074
# 1     Supermarket Type2           443.4228           0.052212  1655.1788
# 2     Supermarket Type1          2097.2700           0.049865  1966.1074
# 4     Supermarket Type1           994.7052           0.106770  2050.6640
# 5     Supermarket Type2           556.6088           0.076030  1655.1788
# ...                 ...                ...                ...        ...
# 8518  Supermarket Type1          2778.3834           0.140795  2050.6640
# 8519  Supermarket Type1           549.2850           0.076030  1834.9448
# 8520  Supermarket Type1          1193.1136           0.061011  2109.2544
# 8521  Supermarket Type2          1845.5976           0.140795  1655.1788
# 8522  Supermarket Type1           765.6700           0.052212  1945.8005
#
#         Item_Type_Cat
# 0         Perishables
# 1     Non_Perishables
# 2         Perishables
# 4     Non_Perishables
# 5     Non_Perishables
# ...               ...
# 8518  Non_Perishables
# 8519  Non_Perishables
# 8520  Non_Perishables
# 8521  Non_Perishables
# 8522  Non_Perishables
#
# [6422 rows x 13 columns]

# %% [markdown]
# ## Removal of Outliers using Z Score
#
# * Step1 - Convert the data into Z score values using StandardScaler/Fn
# * Step2 - Find the Outliers and Eliminate them

# %%
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()

# %%
## Fetch the list of numerical variable only

newsales.select_dtypes(include = np.number).columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales',
#        'Item_Type_Percent', 'Outlet_ID'],
#       dtype='object')

# %%
cols=['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales','Outlet_ID']
for i in cols:
    newsales.loc[:,i]=sc.fit_transform(pd.DataFrame(newsales.loc[:,i]))

# %%
newsales
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0                 FD    -0.766217          Low Fat        -0.970732
# 1                 DR    -1.494175          Regular        -0.908111
# 2                 FD     0.999834          Low Fat        -0.956917
# 3                 FD     1.365966          Regular        -1.281758
# 4                 NC    -0.845905       Non Edible        -1.281758
# ...              ...          ...              ...              ...
# 8518              FD    -1.290648          Low Fat        -0.181193
# 8519              FD    -0.964360          Regular        -0.371154
# 8520              NC    -0.486234       Non Edible        -0.599784
# 8521              FD    -1.216345          Regular         1.532880
# 8522              DR     0.418329          Low Fat        -0.411936
#
#                   Item_Type  Item_MRP Outlet_Size Outlet_Location_Type  \
# 0                     Dairy  1.747454      Medium               Tier 1
# 1               Soft Drinks -1.489023      Medium               Tier 3
# 2                      Meat  0.010040      Medium               Tier 1
# 3     Fruits and Vegetables  0.660050      Medium               Tier 3
# 4                 Household -1.399220        High               Tier 3
# ...                     ...       ...         ...                  ...
# 8518            Snack Foods  1.180783        High               Tier 3
# 8519           Baking Goods -0.527301      Medium               Tier 2
# 8520     Health and Hygiene -0.897208       Small               Tier 2
# 8521            Snack Foods -0.607977      Medium               Tier 3
# 8522            Soft Drinks -1.052261       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales  Item_Type_Percent  Outlet_ID  \
# 0     Supermarket Type1           0.910601           0.080019   0.110162
# 1     Supermarket Type2          -1.018440           0.052212  -0.293273
# 2     Supermarket Type1          -0.049238           0.049865   0.110162
# 3         Grocery Store          -0.849103           0.144550  -2.116073
# 4     Supermarket Type1          -0.695373           0.106770   0.219876
# ...                 ...                ...                ...        ...
# 8518  Supermarket Type1           0.349915           0.140795   0.219876
# 8519  Supermarket Type1          -0.956402           0.076030  -0.060024
# 8520  Supermarket Type1          -0.579100           0.061011   0.295898
# 8521  Supermarket Type2          -0.196725           0.140795  -0.293273
# 8522  Supermarket Type1          -0.829594           0.052212   0.083813
#
#         Item_Type_Cat
# 0         Perishables
# 1     Non_Perishables
# 2         Perishables
# 3         Perishables
# 4     Non_Perishables
# ...               ...
# 8518  Non_Perishables
# 8519  Non_Perishables
# 8520  Non_Perishables
# 8521  Non_Perishables
# 8522  Non_Perishables
#
# [8523 rows x 13 columns]

# %%
localdf = newsales.loc[:,cols]
localdf.loc[~((localdf<-3) | (localdf>3)).any(axis=1)]
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales  Outlet_ID
# 0       -0.766217        -0.970732  1.747454           0.910601   0.110162
# 1       -1.494175        -0.908111 -1.489023          -1.018440  -0.293273
# 2        0.999834        -0.956917  0.010040          -0.049238   0.110162
# 3        1.365966        -1.281758  0.660050          -0.849103  -2.116073
# 4       -0.845905        -1.281758 -1.399220          -0.695373   0.219876
# ...           ...              ...       ...                ...        ...
# 8518    -1.290648        -0.181193  1.180783           0.349915   0.219876
# 8519    -0.964360        -0.371154 -0.527301          -0.956402  -0.060024
# 8520    -0.486234        -0.599784 -0.897208          -0.579100   0.295898
# 8521    -1.216345         1.532880 -0.607977          -0.196725  -0.293273
# 8522     0.418329        -0.411936 -1.052261          -0.829594   0.083813
#
# [8338 rows x 5 columns]

# %%
newsales.drop(['Item_Type'],axis=1,inplace=True)

# %%
finaldata=pd.get_dummies(newsales,drop_first=True)

# %%
finaldata.loc[~((finaldata<-3) | (finaldata>3)).any(axis=1)]
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales  \
# 0       -0.766217        -0.970732  1.747454           0.910601
# 1       -1.494175        -0.908111 -1.489023          -1.018440
# 2        0.999834        -0.956917  0.010040          -0.049238
# 3        1.365966        -1.281758  0.660050          -0.849103
# 4       -0.845905        -1.281758 -1.399220          -0.695373
# ...           ...              ...       ...                ...
# 8518    -1.290648        -0.181193  1.180783           0.349915
# 8519    -0.964360        -0.371154 -0.527301          -0.956402
# 8520    -0.486234        -0.599784 -0.897208          -0.579100
# 8521    -1.216345         1.532880 -0.607977          -0.196725
# 8522     0.418329        -0.411936 -1.052261          -0.829594
#
#       Item_Type_Percent  Outlet_ID  Item_Identifier_FD  Item_Identifier_NC  \
# 0              0.080019   0.110162                   1                   0
# 1              0.052212  -0.293273                   0                   0
# 2              0.049865   0.110162                   1                   0
# 3              0.144550  -2.116073                   1                   0
# 4              0.106770   0.219876                   0                   1
# ...                 ...        ...                 ...                 ...
# 8518           0.140795   0.219876                   1                   0
# 8519           0.076030  -0.060024                   1                   0
# 8520           0.061011   0.295898                   0                   1
# 8521           0.140795  -0.293273                   1                   0
# 8522           0.052212   0.083813                   0                   0
#
#       Item_Fat_Content_Non Edible  Item_Fat_Content_Regular  \
# 0                               0                         0
# 1                               0                         1
# 2                               0                         0
# 3                               0                         1
# 4                               1                         0
# ...                           ...                       ...
# 8518                            0                         0
# 8519                            0                         1
# 8520                            1                         0
# 8521                            0                         1
# 8522                            0                         0
#
#       Outlet_Size_Medium  Outlet_Size_Small  Outlet_Location_Type_Tier 2  \
# 0                      1                  0                            0
# 1                      1                  0                            0
# 2                      1                  0                            0
# 3                      1                  0                            0
# 4                      0                  0                            0
# ...                  ...                ...                          ...
# 8518                   0                  0                            0
# 8519                   1                  0                            1
# 8520                   0                  1                            1
# 8521                   1                  0                            0
# 8522                   0                  1                            0
#
#       Outlet_Location_Type_Tier 3  Outlet_Type_Supermarket Type1  \
# 0                               0                              1
# 1                               1                              0
# 2                               0                              1
# 3                               1                              0
# 4                               1                              1
# ...                           ...                            ...
# 8518                            1                              1
# 8519                            0                              1
# 8520                            0                              1
# 8521                            1                              0
# 8522                            0                              1
#
#       Outlet_Type_Supermarket Type2  Outlet_Type_Supermarket Type3  \
# 0                                 0                              0
# 1                                 1                              0
# 2                                 0                              0
# 3                                 0                              0
# 4                                 0                              0
# ...                             ...                            ...
# 8518                              0                              0
# 8519                              0                              0
# 8520                              0                              0
# 8521                              1                              0
# 8522                              0                              0
#
#       Item_Type_Cat_Perishables
# 0                             1
# 1                             0
# 2                             1
# 3                             1
# 4                             0
# ...                         ...
# 8518                          0
# 8519                          0
# 8520                          0
# 8521                          0
# 8522                          0
#
# [8338 rows x 18 columns]
